# %% [markdown]
# **Задание**:реализовать генетический алгоритм, решающий нелинейное диофантово уравнение.
#             Использовать заданные виды стратегии этапов алгоритма.
#             Необходимо самостоятельно экспериментально подобрать наиболее подходящие размеры популяций,
#             число особей производящих потомков, необходимые вероятности, необходимые размеры замещаемых частей популяции и т.д.
#
# **НП**:          Случайная в (-200,200)
#
# **Селекция**:    Турнирная
#
# **Cкрещивание**: Пропорциональное вероятностное
#
# **Мутация**:     Каждый бит всех потомков мутирует с некоторой вероятностью p
#
# **Замещение**:   Случайно пропорциональным образом создать новую популяцию из предков и потомков

# %%
class Function:
    
    def __init__(self,result,powU,powW,powX,powY,powZ,
                         powU1,powW1,powX1,powY1,powZ1,
                         powU2,powW2,powX2,powY2,powZ2,
                         powU3,powW3,powX3,powY3,powZ3,
                         powU4,powW4,powX4,powY4,powZ4):
        self.result=result
        self.powU=powU
        self.powW=powW
        self.powX=powX
        self.powY=powY
        self.powZ=powZ
        self.powU1=powU1
        self.powW1=powW1
        self.powX1=powX1
        self.powY1=powY1
        self.powZ1=powZ1
        self.powU2=powU2
        self.powW2=powW2
        self.powX2=powX2
        self.powY2=powY2
        self.powZ2=powZ2
        self.powU3=powU3
        self.powW3=powW3
        self.powX3=powX3
        self.powY3=powY3
        self.powZ3=powZ3
        self.powU4=powU4
        self.powW4=powW4
        self.powX4=powX4
        self.powY4=powY4
        self.powZ4=powZ4
    
    def getResult(self):
        return self.result
        
    def getFunction(self):
        print(f"u**{self.powU}*w**{self.powW}*x**{self.powX}*y**{self.powY}*z**{self.powZ}+u**{self.powU1}*w**{self.powW1}*x**{self.powX1}*y**{self.powY1}*z**{self.powZ1}+u**{self.powU2}*w**{self.powW2}*x**{self.powX2}*y**{self.powY2}*z**{self.powZ2}+u**{self.powU3}*w**{self.powW3}*x**{self.powX3}*y**{self.powY3}*z**{self.powZ3}+u**{self.powU4}*w**{self.powW4}*x**{self.powX4}*y**{self.powY4}*z**{self.powZ4}")
        
    def calculateFunction(self,u,w,x,y,z):
        return u**self.powU*w**self.powW*x**self.powX*y**self.powY*z**self.powZ+u**self.powU1*w**self.powW1*x**self.powX1*y**self.powY1*z**self.powZ1+u**self.powU2*w**self.powW2*x**self.powX2*y**self.powY2*z**self.powZ2+u**self.powU3*w**self.powW3*x**self.powX3*y**self.powY3*z**self.powZ3+u**self.powU4*w**self.powW4*x**self.powX4*y**self.powY4*z**self.powZ4

# %%
import random

FROM=-200
TO=200

class Individual:
    def __init__(self,function):
        self.x=random.randint(FROM,TO)
        self.y=random.randint(FROM,TO)
        self.z=random.randint(FROM,TO)
        self.u=random.randint(FROM,TO)
        self.w=random.randint(FROM,TO)
        self.function=function
        self.probability=0
        self.fa=abs(function.calculateFunction(self.u,self.w,self.x,self.y,self.z-function.getResult()))

    def getX(self):
        return self.x
    
    def getY(self):
        return self.y
    
    def getZ(self):
        return self.z
    
    def getU(self):
        return self.u
    
    def getW(self):
        return self.w
                    
    def getFa(self):
        return self.fa
    
    def getProbability(self):
        return self.probability
    
    def setX(self,x):
        self.x=x
        
    def setY(self,y):
        self.y=y
        
    def setZ(self,z):
        self.z=z
        
    def setU(self,u):
        self.u=u
        
    def setW(self,w):
        self.w=w
    
    def setFa(self):
        self.fa=abs(self.function.calculateFunction(self.u,self.w,self.x,self.y,self.z-self.function.getResult()))
    
    def setProbability(self,p):
        self.probability=p
        
    def increaseProbability(self,i):
        self.probability=self.probability*i
                    
    def __str__(self):
        return "(%d,%d,%d,%d,%d); fa=%d" % (self.u,self.w,self.x,self.y,self.z,self.fa)

# %%
POPULATION_SIZE=100
SELECTION=40
NUMBER_OF_SELECTION=10
MAX_REPEAT=100
PROBABILITY_OF_MUTATION=0.1
PROBABILITY_OF_MUTATION_WHILE_NUCLEAR_BLAST=0.75


class Population:
    
    def __init__(self,function):
        self.function=function
        self.population=[Individual(self.function) for i in range(POPULATION_SIZE)]
        self.numberOfGeneration=0
        self.mutation=PROBABILITY_OF_MUTATION
    
    def calculateProbabilityForElement(self,element,elements):
        probability=1/element.getFa()
        denominator=0
        for i in range(len(elements)):
            denominator=denominator+1/elements[i].getFa()
        if denominator==0:
            denominator=1
        probability=probability/denominator
        element.setProbability(probability)
    
    def crossbreeding(self,firstparant,secondparent):
        kid=Individual(self.function)
        self.calculateProbabilityForElement(firstparant,[firstparant,secondparent])
        self.calculateProbabilityForElement(secondparent,[firstparant,secondparent])
        #u
        randomSelect=random.random()
        if firstparant.getProbability()<secondparent.getProbability():
            if randomSelect<=firstparant.getProbability():
                kid.setU(firstparant.getU())
            else:
                kid.setU(secondparent.getU())
        else:
            if randomSelect<=secondparent.getProbability():
                kid.setU(secondparent.getU())
            else:
                kid.setU(firstparant.getU())
        #w
        randomSelect=random.random()
        if firstparant.getProbability()<secondparent.getProbability():
            if randomSelect<=firstparant.getProbability():
                kid.setW(firstparant.getW())
            else:
                kid.setW(secondparent.getW())
        else:
            if randomSelect<=secondparent.getProbability():
                kid.setW(secondparent.getW())
            else:
                kid.setW(firstparant.getW())
        #x
        randomSelect=random.random()
        if firstparant.getProbability()<secondparent.getProbability():
            if randomSelect<=firstparant.getProbability():
                kid.setX(firstparant.getX())
            else:
                kid.setX(secondparent.getX())
        else:
            if randomSelect<=secondparent.getProbability():
                kid.setX(secondparent.getX())
            else:
                kid.setX(firstparant.getX())
        #y
        randomSelect=random.random()
        if firstparant.getProbability()<secondparent.getProbability():
            if randomSelect<=firstparant.getProbability():
                kid.setY(firstparant.getY())
            else:
                kid.setY(secondparent.getY())
        else:
            if randomSelect<=secondparent.getProbability():
                kid.setY(secondparent.getY())
            else:
                kid.setY(firstparant.getY())       
        #z
        randomSelect=random.random()
        if firstparant.getProbability()<secondparent.getProbability():
            if randomSelect<=firstparant.getProbability():
                kid.setZ(firstparant.getZ())
            else:
                kid.setZ(secondparent.getZ())
        else:
            if randomSelect<=secondparent.getProbability():
                kid.setZ(secondparent.getZ())
            else:
                kid.setZ(firstparant.getZ()) 
        kid.setFa()
        return kid
    
    def mutate(self,individual):
        issomethingchange = False
        temp = random.random()
        if temp<=self.mutation:
            issomethingchange=True
            individual.setU(FROM+random.randint(0,TO-FROM+1))
        if temp<=self.mutation:
            issomethingchange=True
            individual.setW(FROM+random.randint(0,TO-FROM+1))
        if temp<=self.mutation:
            issomethingchange=True
            individual.setX(FROM+random.randint(0,TO-FROM+1))
        if temp<=self.mutation:
            issomethingchange=True
            individual.setY(FROM+random.randint(0,TO-FROM+1))
        if temp<=self.mutation:
            issomethingchange=True
            individual.setZ(FROM+random.randint(0,TO-FROM+1))
        if issomethingchange:
            individual.setFa()
#     
#     def getindividual(self,allpopulation):
#         for i in range(len(allpopulation)):
#             self.calculateProbabilityForElement(allpopulation[i],allpopulation)
#             allpopulation[i].increaseProbability(10**11)
#         temp = random.uniform(0,10**11)
#         for j in range(1,len(allpopulation)):
#             if allpopulation[j-1].getProbability()<temp and temp<=allpopulation[j].getProbability():
#                 allpopulation.pop(j)
#                 return allpopulation[j]
#         return allpopulation[0]
        
    def replacegeneration(self,allpopulation):
        numberinnewgeneration=0
        newgeneration=[]
        allpopulation.sort(key=lambda x: x.probability)
        while numberinnewgeneration<=POPULATION_SIZE:
            for i in range(len(allpopulation)):
                self.calculateProbabilityForElement(allpopulation[i],allpopulation)
                allpopulation[i].increaseProbability(10**11)
            temp = random.uniform(0,10**11)
            for j in range(1,len(allpopulation)):
                if allpopulation[j-1].getProbability()<temp and temp<=allpopulation[j].getProbability():
                    newgeneration.append(allpopulation[j])
                    allpopulation.pop(j)
                    break
            newgeneration.append(allpopulation[0])
            numberinnewgeneration=numberinnewgeneration+1
        return newgeneration
    
    def getNewPopulation(self):
        #Селекця
        selectedfromoldgeneration=[]
        self.population.sort(key=lambda x: x.fa)
        for i in range(SELECTION):
            selectedfromoldgeneration.append(self.population[i])
        #Скрещивание
        childrens=[]
        for start in range(len(selectedfromoldgeneration)-1):
            for number in range(NUMBER_OF_SELECTION):
                selectedIndex=random.randint(0,len(selectedfromoldgeneration)-1)
                while selectedIndex==start:
                    selectedIndex=random.randint(0,len(selectedfromoldgeneration)-1)
                childrens.append(self.crossbreeding(selectedfromoldgeneration[start],selectedfromoldgeneration[selectedIndex]))
        #Мутация
        for j in range(len(childrens)):
            self.mutate(childrens[j])
        #Замещение
        childrens.sort(key=lambda x: x.fa)
        return childrens[:POPULATION_SIZE]
#         allindividuals=[]
#         for p in range(len(self.population)):
#             allindividuals.append(self.population[p])
#         for c in range(len(childrens)):
#             allindividuals.append(childrens[c])
#         return self.replacegeneration(allindividuals)
        
    def run(self):
        repeat=0
        isNuclearBlast=False
        self.population.sort(key=lambda x: x.fa)
        self.bestfromall=self.population[0]
        self.bestfromthisgeneration=self.population[0]
        while 1:
            if self.bestfromthisgeneration.getFa()==0:
                break
            if repeat>MAX_REPEAT:
                isNuclearBlast=True
                self.mutation=PROBABILITY_OF_MUTATION_WHILE_NUCLEAR_BLAST
            print("Покаление номер ",self.numberOfGeneration+1,end="")
            newpopulation=self.getNewPopulation()
            self.population.clear()
            for j in range(len(newpopulation)):
                self.population.append(newpopulation[j])
            self.population.sort(key=lambda x: x.fa)
            self.bestfromthisgeneration=self.population[0]
            if self.bestfromthisgeneration.getFa()<self.bestfromall.getFa():
                self.bestfromall=self.bestfromthisgeneration
                repeat=0
            else:
                repeat=repeat+1
            print(f" Лучший из всех поколений: {self.bestfromall}",
                  f" Лучший из {self.numberOfGeneration+1} покаления: {self.bestfromthisgeneration}")
            if isNuclearBlast:
                self.mutation=PROBABILITY_OF_MUTATION
                repeat=0
            self.numberOfGeneration=self.numberOfGeneration+1
        print(f"Решение {self.bestfromall} и количество поколений {self.numberOfGeneration+1}")

# %%
f=Function(-50,1,0,2,2,2,0,0,0,1,0,0,0,1,0,2,0,0,1,2,2,1,2,2,1,2)
p=Population(f)
p.run()
# Out:
# Покаление номер  1 Лучший из всех поколений: (56,-6,4,-33,-34); fa=21592097  Лучший из 1 покаления: (56,-6,4,-33,-34); fa=21592097
# Покаление номер  2 Лучший из всех поколений: (-60,-18,1,-16,-52); fa=1183732  Лучший из 2 покаления: (-60,-18,1,-16,-52); fa=1183732
# Покаление номер  3 Лучший из всех поколений: (56,-6,1,-33,-52); fa=17849  Лучший из 3 покаления: (56,-6,1,-33,-52); fa=17849
# Покаление номер  4 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 4 покаления: (-60,-18,1,0,-52); fa=4
# Покаление номер  5 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 5 покаления: (-60,-18,1,0,-52); fa=4
# Покаление номер  6 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 6 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  7 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 7 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  8 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 8 покаления: (-13,-6,1,0,-52); fa=4
# Покаление номер  9 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 9 покаления: (-13,-6,1,0,-52); fa=4
# Покаление номер  10 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 10 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  11 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 11 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  12 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 12 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  13 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 13 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  14 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 14 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  15 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 15 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  16 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 16 покаления: (-60,-6,1,0,-52); fa=4
# Покаление номер  17 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 17 покаления: (-60,-18,1,0,-52); fa=4
# Покаление номер  18 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 18 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  19 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 19 покаления: (-13,-6,1,0,-52); fa=4
# Покаление номер  20 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 20 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  21 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 21 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  22 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 22 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  23 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 23 покаления: (-13,-6,1,0,-52); fa=4
# Покаление номер  24 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 24 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  25 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 25 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  26 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 26 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  27 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 27 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  28 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 28 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  29 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 29 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  30 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 30 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  31 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 31 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  32 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 32 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  33 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 33 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  34 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 34 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  35 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 35 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  36 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 36 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  37 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 37 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  38 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 38 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  39 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 39 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  40 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 40 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  41 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 41 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  42 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 42 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  43 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 43 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  44 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 44 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  45 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 45 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  46 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 46 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  47 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 47 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  48 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 48 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  49 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 49 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  50 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 50 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  51 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 51 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  52 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 52 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  53 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 53 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  54 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 54 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  55 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 55 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  56 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 56 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  57 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 57 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  58 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 58 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  59 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 59 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  60 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 60 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  61 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 61 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  62 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 62 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  63 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 63 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  64 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 64 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  65 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 65 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  66 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 66 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  67 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 67 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  68 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 68 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  69 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 69 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  70 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 70 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  71 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 71 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  72 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 72 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  73 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 73 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  74 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 74 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  75 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 75 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  76 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 76 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  77 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 77 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  78 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 78 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  79 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 79 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  80 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 80 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  81 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 81 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  82 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 82 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  83 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 83 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  84 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 84 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  85 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 85 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  86 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 86 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  87 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 87 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  88 Лучший из всех поколений: (-60,-18,1,0,-52); fa=4  Лучший из 88 покаления: (-13,-18,1,0,-52); fa=4
# Покаление номер  89 Лучший из всех поколений: (76,151,-12,1,-50); fa=1  Лучший из 89 покаления: (76,151,-12,1,-50); fa=1
# Покаление номер  90 Лучший из всех поколений: (76,-18,-12,0,-50); fa=0  Лучший из 90 покаления: (76,-18,-12,0,-50); fa=0
# Решение (76,-18,-12,0,-50); fa=0 и количество поколений 91

# %%
f=Function(-50,0,1,0,1,0,1,0,2,2,0,1,2,2,0,2,0,2,2,0,1,0,0,0,2,0)
p=Population(f)
p.run()
# Out:
# Покаление номер  1 Лучший из всех поколений: (0,24,-27,-181,-61); fa=4590527  Лучший из 1 покаления: (0,24,-27,-181,-61); fa=4590527
# Покаление номер  2 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 2 покаления: (0,0,-115,4,-61); fa=16
# Покаление номер  3 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 3 покаления: (0,0,-115,4,-61); fa=16
# Покаление номер  4 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 4 покаления: (0,0,-115,4,-61); fa=16
# Покаление номер  5 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 5 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  6 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 6 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  7 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 7 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  8 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 8 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  9 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 9 покаления: (0,0,-27,4,-160); fa=16
# Покаление номер  10 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 10 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  11 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 11 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  12 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 12 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  13 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 13 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  14 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 14 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  15 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 15 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  16 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 16 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  17 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 17 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  18 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 18 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  19 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 19 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  20 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 20 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  21 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 21 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  22 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 22 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  23 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 23 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  24 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 24 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  25 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 25 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  26 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 26 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  27 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 27 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  28 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 28 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  29 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 29 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  30 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 30 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  31 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 31 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  32 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 32 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  33 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 33 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  34 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 34 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  35 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 35 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  36 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 36 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  37 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 37 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  38 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 38 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  39 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 39 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  40 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 40 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  41 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 41 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  42 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 42 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  43 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 43 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  44 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 44 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  45 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 45 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  46 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 46 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  47 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 47 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  48 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 48 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  49 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 49 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  50 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 50 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  51 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 51 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  52 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 52 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  53 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 53 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  54 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 54 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  55 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 55 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  56 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 56 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  57 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 57 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  58 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 58 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  59 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 59 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  60 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 60 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  61 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 61 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  62 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 62 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  63 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 63 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  64 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 64 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  65 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 65 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  66 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 66 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  67 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 67 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  68 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 68 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  69 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 69 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  70 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 70 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  71 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 71 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  72 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 72 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  73 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 73 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  74 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 74 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  75 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 75 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  76 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 76 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  77 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 77 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  78 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 78 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  79 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 79 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  80 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 80 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  81 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 81 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  82 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 82 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  83 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 83 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  84 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 84 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  85 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 85 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  86 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 86 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  87 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 87 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  88 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 88 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  89 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 89 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  90 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 90 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  91 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 91 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  92 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 92 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  93 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 93 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  94 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 94 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  95 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 95 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  96 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 96 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  97 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 97 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  98 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 98 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  99 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 99 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  100 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 100 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  101 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 101 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  102 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 102 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  103 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 103 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  104 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 104 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  105 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 105 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  106 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 106 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  107 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 107 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  108 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 108 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  109 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 109 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  110 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 110 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  111 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 111 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  112 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 112 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  113 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 113 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  114 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 114 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  115 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 115 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  116 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 116 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  117 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 117 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  118 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 118 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  119 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 119 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  120 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 120 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  121 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 121 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер  122 Лучший из всех поколений: (0,0,-115,4,-61); fa=16  Лучший из 122 покаления: (0,0,-115,4,-160); fa=16
# Покаление номер
Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 916 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  917 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 917 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  918 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 918 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  919 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 919 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  920 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 920 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  921 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 921 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  922 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 922 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  923 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 923 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  924 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 924 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  925 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 925 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  926 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 926 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  927 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 927 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  928 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 928 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  929 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 929 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  930 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 930 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  931 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 931 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  932 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 932 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  933 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 933 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  934 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 934 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  935 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 935 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  936 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 936 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  937 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 937 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  938 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 938 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  939 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 939 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  940 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 940 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  941 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 941 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  942 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 942 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  943 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 943 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  944 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 944 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  945 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 945 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  946 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 946 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  947 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 947 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  948 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 948 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  949 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 949 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  950 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 950 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  951 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 951 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  952 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 952 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  953 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 953 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  954 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 954 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  955 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 955 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  956 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 956 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  957 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 957 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  958 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 958 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  959 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 959 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  960 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 960 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  961 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 961 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  962 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 962 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  963 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 963 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  964 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 964 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  965 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 965 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  966 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 966 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  967 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 967 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  968 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 968 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  969 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 969 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  970 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 970 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  971 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 971 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  972 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 972 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  973 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 973 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  974 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 974 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  975 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 975 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  976 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 976 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  977 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 977 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  978 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 978 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  979 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 979 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  980 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 980 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  981 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 981 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  982 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 982 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  983 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 983 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  984 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 984 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  985 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 985 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  986 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 986 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  987 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 987 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  988 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 988 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  989 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 989 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  990 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 990 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  991 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 991 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  992 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 992 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  993 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 993 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  994 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 994 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  995 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 995 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  996 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 996 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  997 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 997 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  998 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 998 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  999 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 999 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1000 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1000 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1001 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1001 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1002 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1002 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1003 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1003 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1004 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1004 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1005 Лучший из всех поколений: (-74,0,36,38,-64); fa=1  Лучший из 1005 покаления: (-74,0,36,38,-64); fa=1
# Покаление номер  1006 Лучший из всех поколений: (115,-1,-61,0,54); fa=0  Лучший из 1006 покаления: (115,-1,-61,0,54); fa=0
# Решение (115,-1,-61,0,54); fa=0 и количество поколений 1007

# %%
f=Function(40,2,2,2,0,1,2,0,1,2,0,0,1,1,1,0,0,0,0,1,0,2,0,2,2,0)
p=Population(f)
p.run()
# Out:
# Покаление номер  1 Лучший из всех поколений: (-3,0,69,-39,8); fa=66117831  Лучший из 1 покаления: (-3,0,69,-39,8); fa=66117831
# Покаление номер  2 Лучший из всех поколений: (-3,0,-24,-5,-133); fa=124195  Лучший из 2 покаления: (-3,0,-24,-5,-133); fa=124195
# Покаление номер  3 Лучший из всех поколений: (111,-27,0,-106,-101); fa=106  Лучший из 3 покаления: (111,-27,0,-106,-101); fa=106
# Покаление номер  4 Лучший из всех поколений: (117,-51,0,60,-141); fa=60  Лучший из 4 покаления: (117,-51,0,60,-141); fa=60
# Покаление номер  5 Лучший из всех поколений: (111,-27,0,-5,-101); fa=5  Лучший из 5 покаления: (111,-27,0,-5,-101); fa=5
# Покаление номер  6 Лучший из всех поколений: (111,-27,0,-5,-101); fa=5  Лучший из 6 покаления: (111,-27,0,-5,-101); fa=5
# Покаление номер  7 Лучший из всех поколений: (111,-27,0,-5,-101); fa=5  Лучший из 7 покаления: (111,-27,0,-5,-101); fa=5
# Покаление номер  8 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 8 покаления: (-181,193,0,4,-43); fa=4
# Покаление номер  9 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из
Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 377 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  378 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 378 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  379 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 379 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  380 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 380 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  381 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 381 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  382 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 382 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  383 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 383 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  384 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 384 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  385 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 385 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  386 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 386 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  387 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 387 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  388 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 388 покаления: (-181,-27,0,4,-101); fa=4
# ...
# Покаление номер  859 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 859 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  860 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 860 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  861 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 861 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  862 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 862 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  863 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 863 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  864 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 864 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  865 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 865 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  866 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 866 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  867 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 867 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  868 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 868 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  869 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 869 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  870 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 870 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  871 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 871 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  872 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 872 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  873 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 873 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  874 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 874 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  875 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 875 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  876 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 876 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  877 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 877 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  878 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 878 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  879 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 879 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  880 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 880 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  881 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 881 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  882 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 882 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  883 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 883 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  884 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 884 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  885 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 885 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  886 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 886 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  887 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 887 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  888 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 888 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  889 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 889 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  890 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 890 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  891 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 891 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  892 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 892 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  893 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 893 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  894 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 894 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  895 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 895 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  896 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 896 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  897 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 897 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  898 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 898 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  899 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 899 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  900 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 900 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  901 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 901 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  902 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 902 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  903 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 903 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  904 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 904 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  905 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 905 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  906 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 906 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  907 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 907 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  908 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 908 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  909 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 909 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  910 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 910 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  911 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 911 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  912 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 912 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  913 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 913 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  914 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 914 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  915 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 915 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  916 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 916 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  917 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 917 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  918 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 918 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  919 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 919 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  920 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 920 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  921 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 921 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  922 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 922 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  923 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 923 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  924 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 924 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  925 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 925 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  926 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 926 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  927 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 927 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  928 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 928 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  929 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 929 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  930 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 930 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  931 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 931 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  932 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 932 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  933 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 933 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  934 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 934 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  935 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 935 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  936 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 936 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  937 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 937 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  938 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 938 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  939 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 939 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  940 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 940 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  941 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 941 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  942 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 942 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  943 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 943 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  944 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 944 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  945 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 945 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  946 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 946 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  947 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 947 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  948 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 948 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  949 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 949 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  950 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 950 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  951 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 951 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  952 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 952 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  953 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 953 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  954 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 954 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  955 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 955 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  956 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 956 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  957 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 957 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  958 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 958 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  959 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 959 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  960 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 960 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  961 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 961 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  962 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 962 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  963 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 963 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  964 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 964 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  965 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 965 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  966 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 966 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  967 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 967 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  968 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 968 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  969 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 969 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  970 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 970 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  971 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 971 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  972 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 972 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  973 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 973 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  974 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 974 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  975 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 975 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  976 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 976 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  977 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 977 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  978 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 978 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  979 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 979 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  980 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 980 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  981 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 981 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  982 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 982 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  983 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 983 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  984 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 984 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  985 Лучший из всех поколений: (-181,193,0,4,-43); fa=4  Лучший из 985 покаления: (-181,-27,0,4,-101); fa=4
# Покаление номер  986 Лучший из всех поколений: (0,138,124,0,129); fa=0  Лучший из 986 покаления: (0,138,124,0,129); fa=0
# Решение (0,138,124,0,129); fa=0 и количество поколений 987

# %%
f=Function(4,1,0,2,1,1,0,0,1,2,1,1,0,0,0,0,2,1,2,2,2,1,1,2,0,0)
p=Population(f)
p.run()
# Out:
# Покаление номер  1 Лучший из всех поколений: (198,156,10,51,4); fa=3088998  Лучший из 1 покаления: (198,156,10,51,4); fa=3088998
# Покаление номер  2 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 2 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  3 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 3 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  4 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 4 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  5 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 5 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  6 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 6 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  7 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 7 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  8 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 8 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  9 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 9 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  10 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 10 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  11 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 11 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  12 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 12 покаления: (-111,-127,10,173,4); fa=1409589
# Покаление номер  13 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 13 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  14 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 14 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  15 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 15 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  16 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 16 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  17 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 17 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  18 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 18 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  19 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 19 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  20 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 20 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  21 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 21 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  22 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 22 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  23 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 23 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  24 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 24 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  25 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 25 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  26 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 26 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  27 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 27 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  28 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 28 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  29 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 29 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  30 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 30 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  31 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 31 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  32 Лучший из всех поколений: (-111,-127,10,173,4); fa=1409589  Лучший из 32 покаления: (-111,-127,10,51,4); fa=1409589
# Покаление номер  33 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 33 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  34 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 34 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  35 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 35 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  36 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 36 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  37 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 37 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  38 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 38 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  39 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 39 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  40 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 40 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  41 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 41 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  42 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 42 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  43 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 43 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  44 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 44 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  45 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 45 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  46 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 46 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  47 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 47 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  48 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 48 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  49 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 49 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  50 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 50 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  51 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 51 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  52 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 52 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  53 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 53 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  54 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 54 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  55 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 55 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  56 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 56 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  57 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 57 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  58 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 58 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  59 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 59 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  60 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 60 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  61 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 61 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  62 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 62 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  63 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 63 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  64 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 64 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  65 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 65 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  66 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 66 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  67 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 67 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  68 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 68 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  69 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 69 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  70 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 70 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  71 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 71 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  72 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 72 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  73 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 73 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  74 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 74 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  75 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 75 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  76 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 76 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  77 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 77 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  78 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 78 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  79 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 79 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  80 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 80 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  81 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 81 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  82 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 82 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  83 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 83 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  84 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 84 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  85 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 85 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  86 Лучший из всех поколений: (-110,19,0,82,3); fa=110  Лучший из 86 покаления: (-110,19,0,82,3); fa=110
# Покаление номер  87 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 87 покаления: (55,85,0,-42,-99); fa=55
# Покаление номер  88 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 88 покаления: (55,85,0,82,-99); fa=55
# Покаление номер  89 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 89 покаления: (55,19,0,82,3); fa=55
# Покаление номер  90 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 90 покаления: (55,19,0,82,3); fa=55
# Покаление номер  91 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 91 покаления: (55,19,0,-42,3); fa=55
# Покаление номер  92 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 92 покаления: (55,19,0,-42,3); fa=55
# Покаление номер  93 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 93 покаления: (55,19,0,82,3); fa=55
# Покаление номер  94 Лучший из всех поколений: (55,85,0,-42,-99); fa=55  Лучший из 94 покаления: (55,19,0,82,3); fa=55
# Покаление номер  95 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 95 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  96 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 96 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  97 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 97 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  98 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 98 покаления: (19,-102,0,-42,3); fa=19
# Покаление номер  99 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 99 покаления: (19,-102,0,-42,3); fa=19
# Покаление номер  100 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 100 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  101 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 101 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  102 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 102 покаления: (19,-102,0,119,3); fa=19
# Покаление номер  103 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 103 покаления: (19,-102,0,-42,3); fa=19
# Покаление номер  104 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 104 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  105 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 105 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  106 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 106 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  107 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 107 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  108 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 108 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  109 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 109 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  110 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 110 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  111 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 111 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  112 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 112 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  113 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 113 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  114 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 114 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  115 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 115 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  116 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 116 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  117 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 117 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  118 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 118 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  119 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 119 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  120 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 120 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  121 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 121 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  122 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 122 покаления: (19,-102,0,-42,65); fa=19
# Покаление номер  123 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 123 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  124 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 124 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  125 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 125 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  126 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 126 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  127 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 127 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  128 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 128 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  129 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 129 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  130 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 130 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  131 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 131 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  132 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из 132 покаления: (19,-102,0,119,65); fa=19
# Покаление номер  133 Лучший из всех поколений: (19,-102,0,119,65); fa=19  Лучший из